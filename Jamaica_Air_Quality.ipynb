# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import plotly.express as px

# %%
df_nyc_air = pd.read_csv('Air_Quality.csv')

# %%
df_nyc_air = df_nyc_air[(df_nyc_air['Geo Place Name'] == 'Jamaica') & (df_nyc_air['Name'] == 'Fine Particulate Matter (PM2.5)')]

# %%
df_nyc_air_1 = pd.DataFrame(data=df_nyc_air, columns=['Start_Date','Data Value'])

# %%
# df_nyc_air_1.sort_values(by='Start_Date', ascending=True, inplace=True)

# %%
df_nyc_air_1['Start_Date_Year'] = df_nyc_air_1['Start_Date']

# %%
# type(df_nyc_air_1['Start_Date'][1])

# %%
# for x in range(len(df_nyc_air_1.index)):
#     df_nyc_air_1['Start_Date_Year'][x] = df_nyc_air_1['Start_Date'][x][6:]

# %%
len(df_nyc_air_1.index)
# Out:
# 60

# %%
df_nyc_air_1.reset_index(drop=True,inplace=True)

# %%
for x in range(len(df_nyc_air_1.index)):
    df_nyc_air_1['Start_Date_Year'][x] = df_nyc_air_1['Start_Date'][x][6:]
# Out:
# <ipython-input-23-d56377cc6611>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nyc_air_1['Start_Date_Year'][x] = df_nyc_air_1['Start_Date'][x][6:]

# %%
df_nyc_air_1.sort_values(by='Start_Date_Year')
# Out:
#     Start_Date  Data Value Start_Date_Year
# 52  12/01/2008       12.69            2008
# 43  12/01/2008        9.95            2008
# 10  12/01/2008       12.69            2008
# 9   12/01/2008        9.95            2008
# 32  12/01/2009        9.25            2009
# 53  12/01/2009        9.68            2009
# 54  06/01/2009       10.13            2009
# 14  06/01/2009       10.13            2009
# 11  12/01/2009        9.68            2009
# 29  12/01/2009        9.25            2009
# 56  06/01/2010       11.39            2010
# 12  12/01/2010       11.87            2010
# 44  12/01/2010        9.57            2010
# 28  06/01/2010       11.39            2010
# 3   12/01/2010        9.57            2010
# 40  12/01/2010       11.87            2010
# 47  12/01/2011        8.80            2011
# 25  12/01/2011        8.80            2011
# 57  12/01/2011        8.48            2011
# 19  06/01/2011       11.15            2011
# 41  06/01/2011       11.15            2011
# 4   12/01/2011        8.48            2011
# 49  12/01/2012        8.27            2012
# 48  12/01/2012        9.79            2012
# 5   12/01/2012        8.27            2012
# 13  12/01/2012        9.79            2012
# 2   06/01/2012        9.98            2012
# 42  06/01/2012        9.98            2012
# 33  12/01/2013       10.93            2013
# 30  12/01/2013       10.93            2013
# 55  06/01/2013       10.07            2013
# 8   06/01/2013       10.07            2013
# 15  12/01/2013        8.46            2013
# 38  12/01/2013        8.46            2013
# 31  06/01/2014        8.10            2014
# 20  12/01/2014        8.63            2014
# 34  06/01/2014        8.10            2014
# 58  12/01/2014        8.63            2014
# 59  12/01/2015        7.42            2015
# 21  12/01/2015        7.42            2015
# 36  06/01/2015        9.08            2015
# 35  01/01/2015        8.20            2015
# 6   01/01/2015        8.20            2015
# 7   12/31/2015        6.99            2015
# 16  06/01/2015        9.08            2015
# 37  12/31/2015        6.99            2015
# 26  12/01/2016        7.93            2016
# 17  12/01/2016        7.93            2016
# 22  05/31/2016        7.57            2016
# 50  05/31/2016        7.57            2016
# 1   01/01/2017        7.08            2017
# 18  12/01/2017        7.71            2017
# 0   06/01/2017        8.62            2017
# 46  01/01/2017        7.08            2017
# 45  06/01/2017        8.62            2017
# 27  12/01/2017        7.71            2017
# 23  01/01/2018        6.69            2018
# 24  06/01/2018        8.25            2018
# 51  01/01/2018        6.69            2018
# 39  06/01/2018        8.25            2018

# %%
df_nyc_air_1.drop(columns=['Start_Date'], inplace=True)

# %%
df_nyc_air_1.sort_values(by='Start_Date_Year', inplace=True)

# %%
df_nyc_air_1
# Out:
#     Data Value Start_Date_Year
# 52       12.69            2008
# 43        9.95            2008
# 10       12.69            2008
# 9         9.95            2008
# 32        9.25            2009
# 53        9.68            2009
# 54       10.13            2009
# 14       10.13            2009
# 11        9.68            2009
# 29        9.25            2009
# 56       11.39            2010
# 12       11.87            2010
# 44        9.57            2010
# 28       11.39            2010
# 3         9.57            2010
# 40       11.87            2010
# 47        8.80            2011
# 25        8.80            2011
# 57        8.48            2011
# 19       11.15            2011
# 41       11.15            2011
# 4         8.48            2011
# 49        8.27            2012
# 48        9.79            2012
# 5         8.27            2012
# 13        9.79            2012
# 2         9.98            2012
# 42        9.98            2012
# 33       10.93            2013
# 30       10.93            2013
# 55       10.07            2013
# 8        10.07            2013
# 15        8.46            2013
# 38        8.46            2013
# 31        8.10            2014
# 20        8.63            2014
# 34        8.10            2014
# 58        8.63            2014
# 59        7.42            2015
# 21        7.42            2015
# 36        9.08            2015
# 35        8.20            2015
# 6         8.20            2015
# 7         6.99            2015
# 16        9.08            2015
# 37        6.99            2015
# 26        7.93            2016
# 17        7.93            2016
# 22        7.57            2016
# 50        7.57            2016
# 1         7.08            2017
# 18        7.71            2017
# 0         8.62            2017
# 46        7.08            2017
# 45        8.62            2017
# 27        7.71            2017
# 23        6.69            2018
# 24        8.25            2018
# 51        6.69            2018
# 39        8.25            2018

# %%
df_nyc_air_1['Data Value'].describe()
# Out:
# count    60.000000
# mean      9.091000
# std       1.487469
# min       6.690000
# 25%       8.100000
# 50%       8.715000
# 75%       9.980000
# max      12.690000
# Name: Data Value, dtype: float64

# %%
df_nyc_air_1.reset_index(drop=True,inplace=True)

# %%
sns.regplot(x=df_nyc_air_1.index, y='Data Value',data=df_nyc_air_1)
# Out:
# <AxesSubplot:ylabel='Data Value'>

# %%
fig, (ax1) = plt.subplots(nrows=1,ncols=1,figsize=(15,8))
ax1  = sns.regplot(x=df_nyc_air_1.index, y='Data Value',data=df_nyc_air_1).set(title='PM2.5 Jamaica,Queens Air Quality over Time [2008-2018]')
