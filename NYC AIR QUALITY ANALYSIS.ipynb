# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import plotly.express as px

# %%
df_nyc_air = pd.read_csv('Air_Quality.csv')

# %%
df_nyc_air.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14289 entries, 0 to 14288
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unique ID       14289 non-null  int64
#  1   Indicator ID    14289 non-null  int64
#  2   Name            14289 non-null  object
#  3   Measure         14289 non-null  object
#  4   Measure Info    14289 non-null  object
#  5   Geo Type Name   14289 non-null  object
#  6   Geo Join ID     14289 non-null  int64
#  7   Geo Place Name  14289 non-null  object
#  8   Time Period     14289 non-null  object
#  9   Start_Date      14289 non-null  object
#  10  Data Value      14289 non-null  float64
#  11  Message         0 non-null      float64
# dtypes: float64(2), int64(3), object(7)
# memory usage: 1.3+ MB

# %%
df_nyc_air
# Out:
#        Unique ID  Indicator ID                                     Name  \
# 0         333939           365          Fine Particulate Matter (PM2.5)
# 1         547354           365          Fine Particulate Matter (PM2.5)
# 2         605650           365          Fine Particulate Matter (PM2.5)
# 3         179503           365          Fine Particulate Matter (PM2.5)
# 4         179643           365          Fine Particulate Matter (PM2.5)
# ...          ...           ...                                      ...
# 14284     131167           655  O3-Attributable Asthma Hospitalizations
# 14285     518596           655  O3-Attributable Asthma Hospitalizations
# 14286     151571           655  O3-Attributable Asthma Hospitalizations
# 14287     628961           655  O3-Attributable Asthma Hospitalizations
# 14288     131168           655  O3-Attributable Asthma Hospitalizations
#
#                                                Measure          Measure Info  \
# ...

# %%
pd.set_option('display.max_rows', 500)
df_nyc_air['Geo Place Name'].value_counts()
# Out:
# Downtown - Heights - Slope                        214
# Kingsbridge - Riverdale                           214
# Washington Heights                                214
# Ridgewood - Forest Hills                          214
# West Queens                                       214
# Long Island City - Astoria                        214
# Bensonhurst - Bay Ridge                           214
# Central Harlem - Morningside Heights              214
# East New York                                     214
# Jamaica                                           214
# Upper West Side                                   214
# East Harlem                                       214
# Southwest Queens                                  214
# Fordham - Bronx Pk                                214
# Williamsburg - Bushwick                           214
# Pelham - Throgs Neck                              214
# East Flatbush - Flatbush                          214
# ...

# %%
df_nyc_air['Name'].value_counts()
# Out:
# Nitrogen Dioxide (NO2)                                                          4230
# Fine Particulate Matter (PM2.5)                                                 4230
# Ozone (O3)                                                                      1551
# Sulfur Dioxide (SO2)                                                            1128
# O3-Attributable Asthma Emergency Department Visits                               384
# O3-Attributable Asthma Hospitalizations                                          384
# PM2.5-Attributable Asthma Emergency Department Visits                            384
# Traffic Density- Annual Vehicle Miles Traveled for Cars                          214
# Traffic Density- Annual Vehicle Miles Traveled                                   209
# Traffic Density- Annual Vehicle Miles Traveled for Trucks                        209
# O3-Attributable Cardiac and Respiratory Deaths                                   192
# ...

# %%
df_nyc_air = df_nyc_air[(df_nyc_air['Geo Place Name'] == 'Jamaica') & (df_nyc_air['Name'] == 'Fine Particulate Matter (PM2.5)')]

# %%
df_nyc_air.reset_index(inplace=True, drop=True)

# %%
df_nyc_air['Data Value'].plot()
# Out:
# <AxesSubplot:>

# %%
df_nyc_air
# Out:
#     Unique ID  Indicator ID                             Name Measure  \
# 0      547566           365  Fine Particulate Matter (PM2.5)    Mean
# 1      547567           365  Fine Particulate Matter (PM2.5)    Mean
# 2      173725           365  Fine Particulate Matter (PM2.5)    Mean
# 3      174201           365  Fine Particulate Matter (PM2.5)    Mean
# 4      174235           365  Fine Particulate Matter (PM2.5)    Mean
# 5      174269           365  Fine Particulate Matter (PM2.5)    Mean
# 6      334150           365  Fine Particulate Matter (PM2.5)    Mean
# 7      410935           365  Fine Particulate Matter (PM2.5)    Mean
# 8      173759           365  Fine Particulate Matter (PM2.5)    Mean
# 9      174133           365  Fine Particulate Matter (PM2.5)    Mean
# 10     173113           365  Fine Particulate Matter (PM2.5)    Mean
# 11     173147           365  Fine Particulate Matter (PM2.5)    Mean
# 12     173181           365  Fine Particulate Matter (PM2.5)    Mean
# ...

# %%
df_nyc_air.plot.line(x='Start_Date', y='Data Value')
# Out:
# <AxesSubplot:xlabel='Start_Date'>

# %%
type(df_nyc_air['Start_Date'][1])
# Out:
# str

# %%
df_nyc_air['Start_Date'][1][6:]
# Out:
# '2017'

# %%
df_nyc_air['Start_Date_Year']=df_nyc_air['Start_Date']
# Out:
# <ipython-input-400-308185354f9f>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nyc_air['Start_Date_Year']=df_nyc_air['Start_Date']

# %%
for x in range(len(df_nyc_air.index)):
    df_nyc_air['Start_Date_Year'][x] = df_nyc_air['Start_Date'][x][6:]
# Out:
# <ipython-input-401-6a3f31525019>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nyc_air['Start_Date_Year'][x] = df_nyc_air['Start_Date'][x][6:]
# C:\Users\booos\anaconda3\envs\learn-env\lib\site-packages\IPython\core\interactiveshell.py:3417: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# df_nyc_air['Start_Date_Year']

# %%
df_nyc_air['Start_Date'] = pd.to_datetime(df_nyc_air['Start_Date'])
# Out:
# <ipython-input-403-68b0e5143761>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nyc_air['Start_Date'] = pd.to_datetime(df_nyc_air['Start_Date'])

# %%
df_nyc_air.sort_values(by='Start_Date')
# Out:
#     Unique ID  Indicator ID                             Name Measure  \
# 43     178434           365  Fine Particulate Matter (PM2.5)    Mean
# 10     173113           365  Fine Particulate Matter (PM2.5)    Mean
# 9      174133           365  Fine Particulate Matter (PM2.5)    Mean
# 52     177174           365  Fine Particulate Matter (PM2.5)    Mean
# 54     177804           365  Fine Particulate Matter (PM2.5)    Mean
# 14     173623           365  Fine Particulate Matter (PM2.5)    Mean
# 11     173147           365  Fine Particulate Matter (PM2.5)    Mean
# 29     174167           365  Fine Particulate Matter (PM2.5)    Mean
# 32     178476           365  Fine Particulate Matter (PM2.5)    Mean
# 53     177216           365  Fine Particulate Matter (PM2.5)    Mean
# 28     173657           365  Fine Particulate Matter (PM2.5)    Mean
# 56     177846           365  Fine Particulate Matter (PM2.5)    Mean
# 44     178518           365  Fine Particulate Matter (PM2.5)    Mean
# ...

# %%
df_nyc_air
# Out:
#     Unique ID  Indicator ID                             Name Measure  \
# 0      547566           365  Fine Particulate Matter (PM2.5)    Mean
# 1      547567           365  Fine Particulate Matter (PM2.5)    Mean
# 2      173725           365  Fine Particulate Matter (PM2.5)    Mean
# 3      174201           365  Fine Particulate Matter (PM2.5)    Mean
# 4      174235           365  Fine Particulate Matter (PM2.5)    Mean
# 5      174269           365  Fine Particulate Matter (PM2.5)    Mean
# 6      334150           365  Fine Particulate Matter (PM2.5)    Mean
# 7      410935           365  Fine Particulate Matter (PM2.5)    Mean
# 8      173759           365  Fine Particulate Matter (PM2.5)    Mean
# 9      174133           365  Fine Particulate Matter (PM2.5)    Mean
# 10     173113           365  Fine Particulate Matter (PM2.5)    Mean
# 11     173147           365  Fine Particulate Matter (PM2.5)    Mean
# 12     173181           365  Fine Particulate Matter (PM2.5)    Mean
# ...

# %%
# df_nyc_air['Data Value'].value_counts()

# %%
# coefficients, residuals, _, _, _ = np.polyfit(range(len(df_nyc_air.index)),df_nyc_air['Data Value'],1,full=True)
# mse = residuals[0]/(len(df_nyc_air['Data Value'].index))
# nrmse = np.sqrt(mse)/(df_nyc_air['Data Value'].max() - df_nyc_air['Data Value'].min())
# print('Slope ' + str(coefficients[0]))
# print('NRMSE: ' + str(nrmse))

# %%
# plt.plot(df_nyc_air['Data Value'])
# plt.plot([coefficients[0]*x + coefficients[1] for x in range(len(df_nyc_air['Data Value']))])
# plt.show()

# %%
# fig, (ax1) = plt.subplots(nrows=1,ncols=1,figsize=(15,8))
# ax1.scatter(df_nyc_air['Start_Date'],df_nyc_air['Data Value'])
# # ax1.plot(X,P(X),"r--")

# %%
# # sns.regplot(df_nyc_air['Start_Date'],df_nyc_air['Data Value'], ci=None)



# X=np.array(df_nyc_air['Start_Date'].astype(int))
# Y=np.array(df_nyc_air['Data Value'])
# Z=np.polyfit(X,Y,1)
# P=np.poly1d(Z)

# %%
fig, (ax1) = plt.subplots(nrows=1,ncols=1,figsize=(15,8))
ax1.scatter(df_nyc_air['Start_Date'],df_nyc_air['Data Value'])
# ax1.plot(X,P(X),"r--")

# %%
df_nyc_air_1 = pd.DataFrame(data=df_nyc_air, columns=['Start_Date','Data Value'])

# %%
df_nyc_air_1
# Out:
#     Start_Date  Data Value
# 0   2017-06-01           8
# 1   2017-01-01           7
# 2   2012-06-01           9
# 3   2010-12-01           9
# 4   2011-12-01           8
# 5   2012-12-01           8
# 6   2015-01-01           8
# 7   2015-12-31           6
# 8   2013-06-01          10
# 9   2008-12-01           9
# 10  2008-12-01          12
# 11  2009-12-01           9
# 12  2010-12-01          11
# 13  2012-12-01           9
# 14  2009-06-01          10
# 15  2013-12-01           8
# 16  2015-06-01           9
# 17  2016-12-01           7
# 18  2017-12-01           7
# 19  2011-06-01          11
# 20  2014-12-01           8
# 21  2015-12-01           7
# 22  2016-05-31           7
# 23  2018-01-01           6
# 24  2018-06-01           8
# 25  2011-12-01           8
# 26  2016-12-01           7
# 27  2017-12-01           7
# 28  2010-06-01          11
# 29  2009-12-01           9
# 30  2013-12-01          10
# 31  2014-06-01           8
# 32  2009-12-01           9
# ...

# %%
df_nyc_air['Data Value'] = df_nyc_air['Data Value'].astype(int)
# Out:
# <ipython-input-325-d23b43b8d7d3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nyc_air['Data Value'] = df_nyc_air['Data Value'].astype(int)

# %%
type(df_nyc_air_1['Start_Date'][1])
# Out:
# str

# %%
df_nyc_air_1.sort_values(by='Start_Date', ascending=True, inplace=True)
df_nyc_air_1.reset_index(inplace=True, drop=True)

# %%
df_nyc_air['Start_Date'] = df_nyc_air['Start_Date'].astype(str)
df_nyc_air['Start_Date']
# Out:
# <ipython-input-332-c75a731982a3>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_nyc_air['Start_Date'] = df_nyc_air['Start_Date'].astype(str)
# 0     2017-06-01
# 1     2017-01-01
# 2     2012-06-01
# 3     2010-12-01
# 4     2011-12-01
# 5     2012-12-01
# 6     2015-01-01
# 7     2015-12-31
# 8     2013-06-01
# 9     2008-12-01
# 10    2008-12-01
# 11    2009-12-01
# 12    2010-12-01
# 13    2012-12-01
# 14    2009-06-01
# 15    2013-12-01
# 16    2015-06-01
# 17    2016-12-01
# 18    2017-12-01
# 19    2011-06-01
# 20    2014-12-01
# 21    2015-12-01
# 22    2016-05-31
# 23    2018-01-01
# 24    2018-06-01
# 25    2011-12-01
# 26    2016-12-01
# 27    2017-12-01
# 28    2010-06-01
# 29    2009-12-01
# 30    2013-12-01
# ...

# %%
df_nyc_air_1.set_index('Start_Date', drop=True, inplace=True)

# %%
df_nyc_air_1
# Out:
#             Data Value
# Start_Date
# 2008-12-01        9.95
# 2008-12-01       12.69
# 2008-12-01        9.95
# 2008-12-01       12.69
# 2009-06-01       10.13
# 2009-06-01       10.13
# 2009-12-01        9.68
# 2009-12-01        9.25
# 2009-12-01        9.25
# 2009-12-01        9.68
# 2010-06-01       11.39
# 2010-06-01       11.39
# 2010-12-01        9.57
# 2010-12-01        9.57
# 2010-12-01       11.87
# 2010-12-01       11.87
# 2011-06-01       11.15
# 2011-06-01       11.15
# 2011-12-01        8.48
# 2011-12-01        8.48
# 2011-12-01        8.80
# 2011-12-01        8.80
# 2012-06-01        9.98
# 2012-06-01        9.98
# 2012-12-01        8.27
# 2012-12-01        8.27
# 2012-12-01        9.79
# 2012-12-01        9.79
# 2013-06-01       10.07
# 2013-06-01       10.07
# 2013-12-01        8.46
# 2013-12-01       10.93
# 2013-12-01        8.46
# 2013-12-01       10.93
# 2014-06-01        8.10
# 2014-06-01        8.10
# 2014-12-01        8.63
# 2014-12-01        8.63
# ...

# %%
sns.regplot(x=df_nyc_air_1.index, y='Data Value',data=df_nyc_air_1)
# Out:
# <AxesSubplot:ylabel='Data Value'>

# %%
sns.regplot(x='Start_Date', y='Data Value',data=df_nyc_air_1)
# Out:
# ---------------------------------------------------------------------------
# UFuncTypeError                            Traceback (most recent call last)
# <ipython-input-335-bf0490ff3926> in <module>
# ----> 1 sns.regplot(x='Start_Date', y='Data Value',data=df_nyc_air_1)
#
# ~\anaconda3\envs\learn-env\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\envs\learn-env\lib\site-packages\seaborn\regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     833     scatter_kws["marker"] = marker
#     834     line_kws = {} if line_kws is None else copy.copy(line_kws)
# ...
